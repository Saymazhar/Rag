# %%
from langchain_community.document_loaders import TextLoader
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv

# %%
model=ChatOpenAI()
prompt=PromptTemplate(template="wrtie a sumamoemry for the following poem -\n {poem}")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 model=ChatOpenAI()
#       2 prompt=PromptTemplate(template="wrtie a sumamoemry for the following poem -\n {poem}")
#
# File d:\Software\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\Software\Lib\site-packages\langchain_openai\chat_models\base.py:1090, in BaseChatOpenAI.validate_environment(self)
#    1080         self.http_async_client = httpx.AsyncClient(
#    1081             proxy=self.openai_proxy, verify=global_ssl_context
#    1082         )
#    1083     async_specific = {
# ...

# %%
from openai import OpenAI

# Read key from file
with open("D:\Mazhar\Rag\Rag\Document_Loader\key", "r") as f:
    line = f.read().strip()
    print(line)

# Extract actual key (remove variable name and quotes)
api_key = line.split("=")[1].replace('"', '')

print("Loaded key:", api_key)  # just to verify

# Create client
client = OpenAI(
    api_key=api_key,
    base_url="https://api.groq.com/openai/v1",
)

# Make request
response = client.responses.create(
    input="Echoes of the Stadium Under lights, the stadium glows,Where every heartbeat faster goes.The crowd roars loud, the drums all play,Its cricket night, its IPL day. make it more bigger "
,
    model="openai/gpt-oss-20b",
)

print(response.output_text)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\itsma\AppData\Local\Temp\ipykernel_13092\3966768949.py:4: SyntaxWarning: invalid escape sequence '\M'
#   with open("D:\Mazhar\Rag\Rag\Document_Loader\key", "r") as f:
# GROQ_API_KEY="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"
# Loaded key: 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
# **Echoes of the Stadium – a Night of Light and Glory**
#
# Echoes of the stadium under lights,
# the arena glows, a sea of neon bright,
# where every heartbeat drums in sync,
# the pulse of the crowd, the rhythm of the rink.
#
# The roar comes thick as thunder’s roar,
# cheers erupt, the drums all play once more,
# the sound waves crash upon the stands,
# a living pulse that shatters all the sands.
#
# Bright floodlights cut the darkness in two,
# a silver‑glimmering field for the brave to pursue;
# the wickets stand tall, the nets await,
# ...

# %%
os.environ.get("GROQ_API_KEY")

# %%
import sys
print(sys.executable)
# Out:
# d:\Software\python.exe

# %%
loader = TextLoader("file.txt", encoding="utf-8")
docs = loader.load()
print(docs)
# Out:
# [Document(metadata={'source': 'file.txt'}, page_content='“Echoes of the Stadium”\n\nUnder lights, the stadium glows,\nWhere every heartbeat faster goes.\nThe crowd roars loud, the drums all play,\nIt’s cricket night, it’s IPL day.\n\nThe pitch lies calm, the battle starts,\nWith fearless minds and lion hearts.\nA bowler runs, with fire in eyes,\nThe ball cuts through like a surprise.\n\nThe bat swings hard, a perfect shot,\nThe crowd erupts — “What a SIX!” they shout.\nFrom covers wide to midwicket sky,\nThe ball takes flight, it seems to fly.\n\nJerseys bright, each team a pride,\nDreams of millions walk beside.\nFrom Mumbai chants to Chennai cheer,\nEvery boundary brings fans near.\n\nLast over now, the tension high,\nWin or lose — no time to sigh.\nOne hit, one ball, the fate decides,\nThe stadium shakes, the moment arrives.\n\nCricket is more than just a game,\nIt’s passion, fire, and endless fame.\nIn IPL nights, the world unites,\nUnder those magical stadium lights.')]

# %%
chain=prompt
